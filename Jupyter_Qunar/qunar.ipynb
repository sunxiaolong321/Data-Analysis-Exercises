# %% [markdown]
# # 去哪儿网站数据分析

# %% [markdown]
# # 国内景点分布

# %%
import pandas as pd
from pyecharts.charts import Bar,Boxplot,WordCloud,Page,Grid,Boxplot,Map,Geo,Tab
from pyecharts import options as opts
import pymysql

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# 链接数据库
connection = pymysql.connect(host='127.0.0.1',port=3306,db='qunar',user='root',password='380324')
cursor = connection.cursor()

# %%
sql = "select city,price from message where price>0"
cursor.execute(sql)
data = pd.DataFrame(cursor.fetchall())

# %%
# 31个省市的价格
prices = data.groupby(data[0]).mean()
bar = Bar()
bar.set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=10,interval=0,rotate=75)),\
                    title_opts=opts.TitleOpts(title="去哪儿网数据分析", subtitle="景点平均价格"),\
                   toolbox_opts=opts.ToolboxOpts(),legend_opts=opts.LegendOpts(is_show=False))
bar.add_yaxis("平均价格",[round(x,2) for x in list(prices[1])]).add_xaxis(list(prices.index),)
bar.set_global_opts()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="95fe14e596444e7f9756eba9ac6e9f21" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_95fe14e596444e7f9756eba9ac6e9f21 = echarts.init(
#                     document.getElementById('95fe14e596444e7f9756eba9ac6e9f21'), 'white', {renderer: 'canvas'});
#                 var option_95fe14e596444e7f9756eba9ac6e9f21 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e73\u5747\u4ef7\u683c",
#             "data": [
#                 104.71,
#                 134.0,
#                 135.2,
#                 79.07,
#                 324.76,
#                 136.45,
#                 104.11,
#                 101.17,
#                 60.71,
#                 71.85,
#                 71.51,
#                 83.48,
#                 83.11,
#                 111.07,
#                 192.47,
#                 62.52,
#                 87.16,
#                 73.04,
#                 66.32,
#                 99.44,
#                 193.31,
#                 89.15,
#                 101.74,
#                 106.47,
#                 90.37,
#                 588.9,
#                 93.62,
#                 87.98,
#                 91.81,
#                 70.2,
#                 143.04,
#                 137.82
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e73\u5747\u4ef7\u683c"
#             ],
#             "selected": {
#                 "\u5e73\u5747\u4ef7\u683c": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 75,
#                 "margin": 8,
#                 "interval": 0,
#                 "fontSize": 10
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77\u5e02",
#                 "\u4e91\u5357\u7701",
#                 "\u5185\u8499\u53e4\u81ea\u6cbb\u533a",
#                 "\u5317\u4eac\u5e02",
#                 "\u53f0\u6e7e\u7701",
#                 "\u5409\u6797\u7701",
#                 "\u56db\u5ddd\u7701",
#                 "\u5929\u6d25\u5e02",
#                 "\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a",
#                 "\u5b89\u5fbd\u7701",
#                 "\u5c71\u4e1c\u7701",
#                 "\u5c71\u897f\u7701",
#                 "\u5e7f\u4e1c\u7701",
#                 "\u5e7f\u897f\u58ee\u65cf\u81ea",
#                 "\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a",
#                 "\u6c5f\u82cf\u7701",
#                 "\u6c5f\u897f\u7701",
#                 "\u6cb3\u5317\u7701",
#                 "\u6cb3\u5357\u7701",
#                 "\u6d59\u6c5f\u7701",
#                 "\u6d77\u5357\u7701",
#                 "\u6e56\u5317\u7701",
#                 "\u6e56\u5357\u7701",
#                 "\u7518\u8083\u7701",
#                 "\u798f\u5efa\u7701",
#                 "\u897f\u85cf\u81ea\u6cbb\u533a",
#                 "\u8d35\u5dde\u7701",
#                 "\u8fbd\u5b81\u7701",
#                 "\u91cd\u5e86\u5e02",
#                 "\u9655\u897f\u7701",
#                 "\u9752\u6d77\u7701",
#                 "\u9ed1\u9f99\u6c5f\u7701"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ]
# };
#                 chart_95fe14e596444e7f9756eba9ac6e9f21.setOption(option_95fe14e596444e7f9756eba9ac6e9f21);
#         });
#     </script>

# %% [markdown]
# 西藏怎么这么贵，可能这就是旅游城市吧，那每个省份选取50*5个数据的结果呢？

# %%
# 32个省市的价格
bar = Bar()
bar.set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=10,interval=0,rotate=75)))
bar.set_global_opts(title_opts=opts.TitleOpts(title="去哪儿网景点价格分析", subtitle="景点平均数"))
for i in range(0,150,50):
    price = []
    cities = []
    for city,prices in data.groupby(data[0]):
        price.append(round(prices[i:i+50][1].mean(),2))
        cities.append(city)
    bar.add_yaxis("前%s条"%(i+50),price)
    bar.set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
            markpoint_opts=opts.MarkPointOpts(
                data=[
                    opts.MarkPointItem(type_="max", name="最大值"),
                    opts.MarkPointItem(type_="min", name="最小值"),
                    opts.MarkPointItem(type_="average", name="平均值"),
                ]
            )
    )
    bar.add_xaxis(cities)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c31da75d682c49f9ba08201bdfffca0f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c31da75d682c49f9ba08201bdfffca0f = echarts.init(
#                     document.getElementById('c31da75d682c49f9ba08201bdfffca0f'), 'white', {renderer: 'canvas'});
#                 var option_c31da75d682c49f9ba08201bdfffca0f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u524d50\u6761",
#             "data": [
#                 118.66,
#                 111.73,
#                 101.16,
#                 57.98,
#                 156.71,
#                 119.42,
#                 102.59,
#                 143.45,
#                 60.25,
#                 64.2,
#                 61.47,
#                 75.24,
#                 82.13,
#                 72.5,
#                 81.94,
#                 60.1,
#                 75.94,
#                 69.57,
#                 66.23,
#                 83.85,
#                 81.92,
#                 76.62,
#                 87.86,
#                 82.1,
#                 75.7,
#                 673.64,
#                 90.98,
#                 70.53,
#                 66.71,
#                 58.53,
#                 160.77,
#                 67.94
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u524d100\u6761",
#             "data": [
#                 71.05,
#                 127.12,
#                 190.96,
#                 63.42,
#                 298.23,
#                 85.45,
#                 66.06,
#                 63.35,
#                 61.93,
#                 83.75,
#                 62.7,
#                 61.76,
#                 79.89,
#                 141.68,
#                 439.06,
#                 56.32,
#                 92.49,
#                 72.19,
#                 59.93,
#                 97.93,
#                 169.68,
#                 76.48,
#                 77.55,
#                 114.61,
#                 71.8,
#                 396.32,
#                 86.1,
#                 72.34,
#                 120.65,
#                 80.12,
#                 54.39,
#                 97.84
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u524d150\u6761",
#             "data": [
#                 71.6,
#                 228.12,
#                 117.72,
#                 58.57,
#                 442.98,
#                 204.47,
#                 102.12,
#                 119.19,
#                 null,
#                 62.32,
#                 70.1,
#                 85.74,
#                 69.81,
#                 91.34,
#                 116.43,
#                 50.4,
#                 72.18,
#                 56.98,
#                 76.02,
#                 97.33,
#                 234.17,
#                 81.28,
#                 87.48,
#                 157.19,
#                 71.79,
#                 null,
#                 91.18,
#                 110.07,
#                 123.44,
#                 65.46,
#                 null,
#                 164.55
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u524d50\u6761",
#                 "\u524d100\u6761",
#                 "\u524d150\u6761"
#             ],
#             "selected": {
#                 "\u524d50\u6761": true,
#                 "\u524d100\u6761": true,
#                 "\u524d150\u6761": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 75,
#                 "margin": 8,
#                 "interval": 0,
#                 "fontSize"

# %% [markdown]
# 西藏景点还真是贵

# %% [markdown]
# ## 销量呢

# %%
sql = "select city,sale from message where sale>0"
cursor.execute(sql)
data = pd.DataFrame(cursor.fetchall())
data = data.astype({1:"double"})

# %%
# 31个省市的销量
sale = data.groupby(data[0]).mean()
bar = Bar()
bar.set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=10,interval=0,rotate=75)))
bar.add_yaxis("平均销量",[round(x,2) for x in list(sale[1])])
bar.add_xaxis(list(sale.index))
bar.set_global_opts(title_opts=opts.TitleOpts(title="去哪儿网数据分析", subtitle="每省份平均销量"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="aeb1fb58fb4740d9aa138cfc97ec5bbd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_aeb1fb58fb4740d9aa138cfc97ec5bbd = echarts.init(
#                     document.getElementById('aeb1fb58fb4740d9aa138cfc97ec5bbd'), 'white', {renderer: 'canvas'});
#                 var option_aeb1fb58fb4740d9aa138cfc97ec5bbd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e73\u5747\u9500\u91cf",
#             "data": [
#                 517.51,
#                 149.07,
#                 56.85,
#                 350.45,
#                 61.45,
#                 113.3,
#                 220.51,
#                 93.46,
#                 162.03,
#                 158.7,
#                 98.39,
#                 110.64,
#                 458.75,
#                 126.97,
#                 164.1,
#                 227.84,
#                 162.31,
#                 92.41,
#                 90.95,
#                 270.24,
#                 315.69,
#                 151.82,
#                 154.93,
#                 65.33,
#                 161.61,
#                 98.04,
#                 127.24,
#                 145.29,
#                 161.44,
#                 245.55,
#                 160.5,
#                 93.89
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e73\u5747\u9500\u91cf"
#             ],
#             "selected": {
#                 "\u5e73\u5747\u9500\u91cf": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 75,
#                 "margin": 8,
#                 "interval": 0,
#                 "fontSize": 10
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77\u5e02",
#                 "\u4e91\u5357\u7701",
#                 "\u5185\u8499\u53e4\u81ea\u6cbb\u533a",
#                 "\u5317\u4eac\u5e02",
#                 "\u53f0\u6e7e\u7701",
#                 "\u5409\u6797\u7701",
#                 "\u56db\u5ddd\u7701",
#                 "\u5929\u6d25\u5e02",
#                 "\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a",
#                 "\u5b89\u5fbd\u7701",
#                 "\u5c71\u4e1c\u7701",
#                 "\u5c71\u897f\u7701",
#                 "\u5e7f\u4e1c\u7701",
#                 "\u5e7f\u897f\u58ee\u65cf\u81ea",
#                 "\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a",
#                 "\u6c5f\u82cf\u7701",
#                 "\u6c5f\u897f\u7701",
#                 "\u6cb3\u5317\u7701",
#                 "\u6cb3\u5357\u7701",
#                 "\u6d59\u6c5f\u7701",
#                 "\u6d77\u5357\u7701",
#                 "\u6e56\u5317\u7701",
#                 "\u6e56\u5357\u7701",
#                 "\u7518\u8083\u7701",
#                 "\u798f\u5efa\u7701",
#                 "\u897f\u85cf\u81ea\u6cbb\u533a",
#                 "\u8d35\u5dde\u7701",
#                 "\u8fbd\u5b81\u7701",
#                 "\u91cd\u5e86\u5e02",
#                 "\u9655\u897f\u7701",
#                 "\u9752\u6d77\u7701",
#                 "\u9ed1\u9f99\u6c5f\u7701"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u53bb\u54ea\u513f\u7f51\u6570\u636e\u5206\u6790",
#             "subtext": "\u6bcf\u7701\u4efd\u5e73\u5747\u9500\u91cf"
#         }
#     ]
# };
#                 chart_aeb1fb58fb4740d9aa138cfc97ec5bbd.setOption(option_aeb1fb58fb4740d9aa138cfc97ec5bbd);
#         });
#     </script>

# %%
那每个省份选取50*5个数据的结果呢

# %%
# 32个省市的价格
bar = Bar()
bar.set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=10,interval=0,rotate=75)))
bar.set_global_opts(title_opts=opts.TitleOpts(title="去哪儿网景点价格分析", subtitle="景点平均数"))
for i in range(0,150,50):
    price = []
    cities = []
    for city,prices in data.groupby(data[0]):
        price.append(round(prices[i:i+50][1].mean(),2))
        cities.append(city)
    bar.add_yaxis("前%s条"%(i+50),price)
    bar.set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
            markpoint_opts=opts.MarkPointOpts(
                data=[
                    opts.MarkPointItem(type_="max", name="最大值"),
                    opts.MarkPointItem(type_="min", name="最小值"),
                    opts.MarkPointItem(type_="average", name="平均值"),
                ]
            )
    )
    bar.add_xaxis(cities)
bar.add_yaxis("地区最大销量",[float(data) for data in data.groupby(data[0]).max().values])
bar.add_xaxis(cities)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0d8e564251ae4f7eaf90eb645d91057f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0d8e564251ae4f7eaf90eb645d91057f = echarts.init(
#                     document.getElementById('0d8e564251ae4f7eaf90eb645d91057f'), 'white', {renderer: 'canvas'});
#                 var option_0d8e564251ae4f7eaf90eb645d91057f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u524d50\u6761",
#             "data": [
#                 1768.66,
#                 114.06,
#                 57.2,
#                 2197.68,
#                 53.14,
#                 35.78,
#                 1414.94,
#                 185.52,
#                 206.36,
#                 188.8,
#                 132.24,
#                 206.78,
#                 1825.68,
#                 134.8,
#                 40.28,
#                 369.4,
#                 768.24,
#                 103.6,
#                 351.6,
#                 226.0,
#                 168.04,
#                 872.42,
#                 215.76,
#                 79.56,
#                 668.68,
#                 120.62,
#                 437.1,
#                 690.7,
#                 52.84,
#                 185.68,
#                 181.68,
#                 226.68
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u524d100\u6761",
#             "data": [
#                 124.76,
#                 38.86,
#                 58.26,
#                 263.48,
#                 64.48,
#                 243.34,
#                 143.56,
#                 82.3,
#                 45.37,
#                 582.94,
#                 259.8,
#                 127.36,
#                 365.8,
#                 71.12,
#                 245.26,
#                 1139.0,
#                 55.84,
#                 156.56,
#                 40.46,
#                 1158.08,
#                 222.28,
#                 129.04,
#                 51.2,
#                 53.88,
#                 163.36,
#                 46.73,
#                 40.42,
#                 84.84,
#                 563.1,
#                 27.84,
#                 54.6,
#                 55.84
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u524d150\u6761",
#             "data": [
#                 54.12,
#                 59.92,
#                 58.82,
#                 55.66,
#                 64.28,
#                 62.5,
#                 54.36,
#                 47.46,
#                 null,
#                 86.12,
#                 75.36,
#                 66.88,
#                 285.16,
#                 44.76,
#                 218.76,
#                 79.56,
#                 40.82,
#                 46.22,
#                 46.42,
#                 468.5,
#                 848.68,
#                 53.2,
#                 38.34,
#                 56.62,
#                 157.58,
#                 null,
#                 43.22,
#                 48.02,
#                 79.6,
#                 37.82,
#                 null,
#                 54.4
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5730\u533a\u6700\u5927\u9500\u91cf",
#             "data": [
#                 57828.0,
#                 5154.0,
#                 460.0,
#                 24145.0,
#                 99.0,
#                 3147.0,
#                 14013.0,
#                 2906.0,
#                 4540.0,
#                 7039.0,
#                 3802.0,
#                 2136.0,
#                 11914.0,
#                 5223.0,
#                 3758.0,
#                 7305.0,
#                 10616.0,
#                 2282.0,
#                 1886.0,
#                 22369.0,
#                 6734.0,
#                 14390.0,
#                 5942.0,
#                 698.0,
#                 4664.0,
#                 2337.0,
#                 2678.0,
#                 8906.0,
#                 7810.0,
#                 16939.0,
#                 2393.0,
#                 1306.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,

# %% [markdown]
# ### 将价格和销量合并在一起来看（只关注有销量和有价格的）

# %%
sql = "select city,price,sale from message where price>=1 and sale>=1"
cursor.execute(sql)
data = pd.DataFrame(cursor.fetchall())
data = data.astype({2:"double"})

# %%
sale_price = data.groupby(data[0]).mean()
bar = (
    Bar()
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=10,interval=0,rotate=75)),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        title_opts=opts.TitleOpts(title="去哪儿网数据分析"),
        toolbox_opts=opts.ToolboxOpts(),
        datazoom_opts=opts.DataZoomOpts(type_="inside")
    )
    .add_xaxis(list(sale_price.index))
    .add_yaxis("平均价格",[round(x,2) for x in list(sale_price[1])],yaxis_index=0,color="#675bba")
    .add_yaxis("平均销量",[round(x,2) for x in list(sale_price[2])],yaxis_index=1,color="#34d3f3")
#     .extend_axis(
#         yaxis=opts.AxisOpts(
#             type_="value",
#             name="平均价格",
#             min_=0,
#             max_=600,
#             position="left",
#             axisline_opts=opts.AxisLineOpts(
#                 linestyle_opts=opts.LineStyleOpts(color="#675bba")
#             ),
#             axislabel_opts=opts.LabelOpts(formatter="{value} 元"),
#             splitline_opts=opts.SplitLineOpts(
#                 is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
#             ),
#         )
#     )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .extend_axis(
        yaxis=opts.AxisOpts(
            type_="value",
            name="平均销量",
            min_=0,
            max_=600,
            position="right",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#34d3f3")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value} 次"),
        )
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fdb2c6ec412a475399366477a671d93c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fdb2c6ec412a475399366477a671d93c = echarts.init(
#                     document.getElementById('fdb2c6ec412a475399366477a671d93c'), 'white', {renderer: 'canvas'});
#                 var option_fdb2c6ec412a475399366477a671d93c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#34d3f3",
#         "#675bba",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e73\u5747\u4ef7\u683c",
#             "yAxisIndex": 0,
#             "data": [
#                 105.18,
#                 134.0,
#                 135.2,
#                 81.99,
#                 328.08,
#                 136.45,
#                 104.59,
#                 104.35,
#                 60.71,
#                 72.06,
#                 71.7,
#                 83.86,
#                 84.26,
#                 111.35,
#                 192.47,
#                 63.14,
#                 87.16,
#                 73.37,
#                 66.51,
#                 99.95,
#                 193.31,
#                 89.35,
#                 102.59,
#                 106.47,
#                 91.54,
#                 588.9,
#                 94.4,
#                 88.44,
#                 92.5,
#                 70.45,
#                 143.04,
#                 139.12
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5e73\u5747\u9500\u91cf",
#             "yAxisIndex": 1,
#             "data": [
#                 519.81,
#                 149.07,
#                 56.85,
#                 362.9,
#                 61.36,
#                 113.3,
#                 221.49,
#                 93.37,
#                 162.03,
#                 159.08,
#                 98.63,
#                 110.51,
#                 464.4,
#                 127.11,
#                 164.1,
#                 229.36,
#                 162.31,
#                 92.63,
#                 91.02,
#                 271.46,
#                 315.69,
#                 152.15,
#                 155.62,
#                 65.33,
#                 160.48,
#                 98.04,
#                 128.25,
#                 145.8,
#                 162.14,
#                 225.52,
#                 160.5,
#                 94.53
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e73\u5747\u4ef7\u683c",
#                 "\u5e73\u5747\u9500\u91cf"
#             ],
#             "selected": {
#                 "\u5e73\u5747\u4ef7\u683c": true,
#                 "\u5e73\u5747\u9500\u91cf": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 75,
#                 "margin": 8,
#                 "interval": 0,
#                 "fontSize": 10
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77\u5e02",
#                 "\u4e91\u5357\u7701",
#                 "\u5185\u8499\u53e4\u81ea\u6cbb\u533a",
#                 "\u5317\u4eac\u5e02",
#                 "\u53f0\u6e7e\u7701",
#                 "\u5409\u6797\u7701",
#                 "\u56db\u5ddd\u7701",
#                 "\u5929\u6d25\u5e02",
#                 "\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a",
#                 "\u5b89\u5fbd\u7701",
#                 "\u5c71\u4e1c\u7701",
#                 "\u5c71\u897f\u7701",
#                 "\u5e7f\u4e1c\u7701",
#                 "\u5e7f\u897f\u58ee\u65cf\u81ea",
#                 "\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a",
#                 "\u6c5f\u82cf\u7701",
#                 "\u6c5f\u897f\u7701",
#                 "\u6cb3\u5317\u7701",
#                 "\u6cb3\u5357\u7701",
#                 "\u6d59\u6c5f\u7701",
#                 "\u6d77\u5357\u7701",
#                 "\u6e56\u5317\u7701",
#                 "\u6e56\u5357\u7701",
#                 "\u7518\u8083\u7701",
#                 "\u798f\u5efa\u7701",
#                 "\u897f\u85cf\u81ea\u6cbb\u533a",
#                 "\u8d35\u5dde\u7701",
#                 "\u8fbd\u5b81\u7701",
#                 "\u91cd\u5e86\u5e02",
#                 "\u9655\u897f\u7701",
#                 "\u9752\u6d77\u7701",
#                 "\u9ed1\u9f99\u6c5f\u7701"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "value",
#             "name": "\u5e73\u5747\u9500\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#34d3f3"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} \u6b21"
#             },
#             "inverse": false,
#             "position": "right",
#             "offset":

# %%
sql = """
SELECT m1.city,m1.price
FROM message m1
WHERE 50>(
    SELECT COUNT(1)
    FROM message m2
    WHERE m1.`city`=m2.`city` AND m1.`price`<m2.`price`
    ORDER BY price
    )
ORDER BY m1.city,m1.price;
"""
cursor.execute(sql)
price = pd.DataFrame(cursor.fetchall())

sql="""
SELECT city,sale
FROM message;
"""
cursor.execute(sql)
sale = pd.DataFrame(cursor.fetchall(),columns=["城市","销量"])
sale = sale.astype({"销量":"double"})

# %%
## 取销量最高的50组价格和销量对比

# %%
box = (
    Boxplot()
    .add_xaxis([x for x,y in price.groupby(data[0])[1]])
    .add_yaxis("平均价格",box.prepare_data([list(y.values) for x,y in price.groupby(data[0])[1]]))
    .add_yaxis("平均销量",box.prepare_data([list(y[:50].values) for x,y in sale.groupby(sale["城市"])["销量"]]))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="销量价格箱型图"),
        datazoom_opts=opts.DataZoomOpts(type_="inside"),
        xaxis_opts = opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=10,interval=0,rotate=75))
    )
)
box.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="80e35633bdb34dc78ffa2df7b482d875" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_80e35633bdb34dc78ffa2df7b482d875 = echarts.init(
#                     document.getElementById('80e35633bdb34dc78ffa2df7b482d875'), 'white', {renderer: 'canvas'});
#                 var option_80e35633bdb34dc78ffa2df7b482d875 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u5e73\u5747\u4ef7\u683c",
#             "data": [
#                 [
#                     120.0,
#                     145.0,
#                     184.0,
#                     319.25,
#                     1398.0
#                 ],
#                 [
#                     248.0,
#                     280.0,
#                     320.0,
#                     450.0,
#                     1380.0
#                 ],
#                 [
#                     120.0,
#                     139.75,
#                     214.0,
#                     326.0,
#                     1780.0
#                 ],
#                 [
#                     140.0,
#                     168.0,
#                     198.0,
#                     285.5,
#                     1380.0
#                 ],
#                 [
#                     816.0,
#                     866.0,
#                     956.0,
#                     1126.0,
#                     2806.0
#                 ],
#                 [
#                     117.0,
#                     138.0,
#                     185.0,
#                     448.0,
#                     1188.0
#                 ],
#                 [
#                     187.0,
#                     216.0,
#                     279.0,
#                     458.5,
#                     2080.0
#                 ],
#                 [
#                     98.0,
#                     108.0,
#                     148.0,
#                     178.0,
#                     2980.0
#                 ],
#                 [
#                     28.0,
#                     39.675,
#                     61.5,
#                     91.25,
#                     315.0
#                 ],
#                 [
#                     110.0,
#                     120.0,
#                     159.0,
#                     193.0,
#                     780.0
#                 ],
#                 [
#                     128.0,
#                     138.0,
#                     170.0,
#                     230.0,
#                     429.0
#                 ],
#                 [
#                     99.0,
#                     115.0,
#                     144.5,
#                     256.0,
#                     680.0
#                 ],
#                 [
#                     168.0,
#                     184.60000000000002,
#                     227.0,
#                     273.0,
#                     465.0
#                 ],
#                 [
#                     175.0,
#                     188.0,
#                     261.5,
#                     368.5,
#                     2688.0
#                 ],
#                 [
#                     110.0,
#                     160.0,
#                     249.0,
#                     429.0,
#                     3480.0
#                 ],
#                 [
#                     108.0,
#                     130.0,
#                     158.0,
#                     200.0,
#                     830.0
#                 ],
#                 [
#                     150.0,
#                     165.0,
#                     203.0,
#                     239.0,
#                     479.0
#                 ],
#                 [
#                     120.0,
#                     138.25,
#                     157.0,
#                     198.75,
#                     3460.0
#                 ],
#                 [
#                     108.0,
#                     120.0,
#                     150.0,
#                     229.8,
#                     680.0
#                 ],
#                 [
#                     188.0,
#                     224.0,
#                     265.0,
#                     355.0,
#                     660.0
#                 ],
#                 [
#                     165.0,
#                     195.5,
#                     293.0,
#                     582.0,
#                     4500.0
#                 ],
#                 [
#                     158.0,
#                     170.0,
#                     205.0,
#                     300.0,
#                     858.0
#                 ],
#                 [
#                     198.0,
#                     208.0,
#                     265.0,
#                     354.5,
#                     678.0
#                 ],
#                 [
#                     58.0,
#                     68.75,
#                     114.0,
#                     229.75,
#                     1398.0
#                 ],
#                 [
#                     148.0,
#                     167.25,
#                     197.5,
#                     394.5,
#                     1299.0
#                 ],
#                 [
#                     188.0,
#                     249.0,
#                     469.0,
#                     1099.0,
#                     2200.0
#                 ],
#                 [
#                     130.0,
#                     158.0,
#                     178.0,
#                     216.5,
#                     880.0
#                 ],
#                 [
#                     145.0,
#                     158.0,
#                     198.0,
#                     379.5,
#                     820.0
#                 ],
#                 [
#                     113.0,
#                     147.5,
#                     168.0,
#                     265.0,
#                     1549.0
#                 ],
#                 [
#                     105.0,
#                     120.0,
#                     149.0,
#                     181.25,
#                     800.0
#                 ],
#                 [
#                     20.0,
#                     33.0,
#                     65.0,
#                     120.5,
#                     2980.0
#                 ],
#                 [
#                     118.0,
#                     150.0,
#                     179.0,
#                     632.25,
#                     2380.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "\u5e73\u5747\u9500\u91cf",
#             "data": [
#                 [
#                     2.0,
#                     17.5,
#                     79.0,
#                     416.0,
#                     57828.0
#                 ],
#                 [
#                     4.0,
#                     23.5,
#                     56.0,
#                     149.0,
#                     496.0

# %%
sql = "select city,price,sale from message where sale>0 or price>0"
cursor.execute(sql)
data = pd.DataFrame(cursor.fetchall(),columns=["省市","单价","销量"])
data = data.astype({"销量":"double"},copy=True)

# %%
price = data["单价"].groupby(data["省市"]).mean()
sale = data["销量"].groupby(data["省市"]).mean()

# %%
def change(lis):
    if lis[0] == "广西壮族自":
        lis[0]="广西"
    elif lis[0] == "内蒙古自治区":
        lis[0] = "内蒙古"
    elif lis[0][-1] != "区":
        lis[0] = lis[0][:-1]
    else:
        lis[0] = lis[0][:2]
    lis[1] = round(lis[1],2)
    return lis

# %%
map = (
    Map()
    .add(
        series_name = "平均价格",
        data_pair = [change(list(x)) for x in zip(price.index,price.values)]
    )
    .add(
    series_name = "平均销量",
    data_pair = [change(list(x)) for x in zip(sale.index,sale.values)]
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="各省市平均价格—销量"),
        visualmap_opts=opts.VisualMapOpts(max_=200)
    )
)
map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="0132733271b242e583aeb01611151f9b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_0132733271b242e583aeb01611151f9b = echarts.init(
#                     document.getElementById('0132733271b242e583aeb01611151f9b'), 'white', {renderer: 'canvas'});
#                 var option_0132733271b242e583aeb01611151f9b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5e73\u5747\u4ef7\u683c",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 104.71
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 134.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 135.2
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 79.07
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 324.76
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 136.45
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 104.11
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 101.17
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 60.71
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 71.85
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 71.51
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 83.48
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 83.11
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 111.07
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 192.47
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 62.52
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 87.16
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 73.04
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 66.32
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 99.44
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 193.31
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 89.15
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 101.74
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 106.47
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 90.37
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 588.9
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 93.62
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 87.98
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 91.81
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 70.2
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 143.04
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 137.82
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         },
#         {
#             "type": "map",
#             "name": "\u5e73\u5747\u9500\u91cf",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 517.51
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 149.07
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 56.85
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 350.45
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 61.45
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 113.3
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 220.51
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 93.46
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 162.03
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 158.7
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 98.39
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 110.64
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 458.75
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 126.97
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 164.1
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 227.84
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 162.31
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 92.41
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 90.95
#                 },

# %%
sql = "select city,note from message where note is not null"
cursor.execute(sql)
data = pd.DataFrame(cursor.fetchall())

# %%
# 统计词频，使用jieba分词库
import jieba
import re
# 处理标点符号
opts.ToolboxOpts(is_show=True)
charts = Page("去哪儿网评论词云",layout=Page.SimplePageLayout)
for city,message in data.groupby(data[0])[1]:
    va_count = {}
    for value in message.values:
        value = re.sub("[\s+\.【】。、》《\!\/_：\d\",$%^*(-+\"\'；“”‘’+|[+=！，。？、~@#￥%……&*（）]+", "",value)
        for z in jieba.lcut(value):
            if z not in ["的",""," ","一个","一","我","你","他","了","只","让","它","从","似","","和","为",\
                     "及","不","吧","很","使","有","在","以","去","级","带","是","与","内","着","之","才",\
                        "能","给","都","还","来","此","于","位于","一座","之一","而","处","能","这","还有","里",\
                         "该","并","其"] and not isinstance(z,int):
                va_count[z] = va_count.get(z,0)+1
    word = list(zip(va_count.keys(),va_count.values()))
    pic = WordCloud(opts.InitOpts(width="300px",height="200px")).\
    add(series_name="%s词云"%city,data_pair=word,shape = "diamond",word_size_range=[5,30]).\
    set_global_opts(title_opts=opts.TitleOpts(title="%s词云"%city))
    charts.add(pic)
charts.render()
# Out:
# 'E:\\python\\render.html'

# %% [markdown]
# # 景点数地图

# %%
sql = "select place,city from message where place is not null and city is not null"
cursor.execute(sql)
data = pd.DataFrame(cursor.fetchall(),columns=["地区","省份"])

# %%
view = data.groupby(data["省份"])

# %%
tab = Tab() 
for x,y in view:
    city_dict = {}
    if x[-3:] == "自治区" or x == "广西壮族自":
        continue
    for city in y["地区"].values:
        if x not in ["上海市","北京市","重庆市","天津市"]:
            try:
                area = re.search("·(.*)·",city).group(1)
            except AttributeError:
                area = re.search("·(.*)",city).group(1)
        else:
            try:
                area = re.search(".*·.*·(.*)",city).group(1)
            except AttributeError:
                pass
        if area[-1:]!="区" and area[-1:]!="县":
            area = area+"市"
        city_dict[area] = city_dict.get(area,0)+1
#     print(city_dict)
    map = (
    Map()
    .add(
        series_name = "地图",
        data_pair = list(zip(city_dict.keys(),city_dict.values())),
        maptype = x[:-1],
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title=x),
                    visualmap_opts=opts.VisualMapOpts())
    )
    tab.add(map,x)
tab.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai', '云南':'https://assets.pyecharts.org/assets/maps/yunnan', '北京':'https://assets.pyecharts.org/assets/maps/beijing', '台湾':'https://assets.pyecharts.org/assets/maps/taiwan', '吉林':'https://assets.pyecharts.org/assets/maps/jilin', '四川':'https://assets.pyecharts.org/assets/maps/sichuan', '天津':'https://assets.pyecharts.org/assets/maps/tianjin', '安徽':'https://assets.pyecharts.org/assets/maps/anhui', '山东':'https://assets.pyecharts.org/assets/maps/shandong', '山西':'https://assets.pyecharts.org/assets/maps/shanxi', '广东':'https://assets.pyecharts.org/assets/maps/guangdong', '江苏':'https://assets.pyecharts.org/assets/maps/jiangsu', '江西':'https://assets.pyecharts.org/assets/maps/jiangxi', '河北':'https://assets.pyecharts.org/assets/maps/hebei', '河南':'https://assets.pyecharts.org/assets/maps/henan', '浙江':'https://assets.pyecharts.org/assets/maps/zhejiang', '海南':'https://assets.pyecharts.org/assets/maps/hainan', '湖北':'https://assets.pyecharts.org/assets/maps/hubei', '湖南':'https://assets.pyecharts.org/assets/maps/hunan', '甘肃':'https://assets.pyecharts.org/assets/maps/gansu', '福建':'https://assets.pyecharts.org/assets/maps/fujian', '贵州':'https://assets.pyecharts.org/assets/maps/guizhou', '辽宁':'https://assets.pyecharts.org/assets/maps/liaoning', '重庆':'https://assets.pyecharts.org/assets/maps/chongqing', '陕西':'https://assets.pyecharts.org/assets/maps/shanxi1', '青海':'https://assets.pyecharts.org/assets/maps/qinghai', '黑龙江':'https://assets.pyecharts.org/assets/maps/heilongjiang'
#         }
#     });
# </script>
#
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
#             padding: 6px 12px;
#             border-top: none;
#         }
#     </style>
# <div class="tab">
#             <button class="tablinks" onclick="showChart(event, '230a4ae03d3a42fbb4f938605a12e93a')">上海市</button>
#             <button class="tablinks" onclick="showChart(event, 'dc74811c4c374729b2b95da312cdd44a')">云南省</button>
#             <button class="tablinks" onclick="showChart(event, '3af75c85c0a54795a820783581385470')">北京市</button>
#             <button class="tablinks" onclick="showChart(event, '8b1b83f6f6e34894a3f2be5bc48e3434')">台湾省</button>
#             <button class="tablinks" onclick="showChart(event, '9df5a6a829374e6d842f865ececadce8')">吉林省</button>
#             <button class="tablinks" onclick="showChart(event, '85eb276e378a4f5baaabaef1080f177a')">四川省</button>
#             <button class="tablinks" onclick="showChart(event, '9544e813a1ee4871aefe15eea149ffc3')">天津市</button>
#             <button class="tablinks" onclick="showChart(event, '69b86ff87428479c98cd6afdd4d3fb4e')">安徽省</button>
#             <button class="tablinks" onclick="showChart(event, '68e3d9eb654347059b7ff4e536599966')">山东省</button>
#             <button class="tablinks" onclick="showChart(event, 'd07627d02e734b06ab3d0ea216f3ba4d')">山西省</button>
#             <button class="tablinks" onclick="showChart(event, '8eb41c448e8a4e61b29342942edca305')">广东省</button>
#             <button class="tablinks" onclick="showChart(event, '517b6a8186844203b552fe045cf2ff63')">江苏省</button>
#             <button class="tablinks" onclick="showChart(event, 'f54a4169873e4e03a1989301d244354f')">江西省</button>
#             <button class="tablinks" onclick="showChart(event, '21550f79d429466e8082efc08978a59a')">河北省</button>
#             <button class="tablinks" onclick="showChart(event, 'a72a4b28ad284474867d3cb6b89e873c')">河南省</button>
#             <button class="tablinks" onclick="showChart(event, '1b2d5e24960c45ad9d56a757cec47b69')">浙江省</button>
#             <button class="tablinks" onclick="showChart(event, 'a14428bf62c04651a17044416a76f187')">海南省</button>
#             <button class="tablinks" onclick="showChart(event, '3a049cda910b43ac92f8de648008d0cc')">湖北省</button>
#             <button class="tablinks" onclick="showChart(event, '0f63742aa76a4729bfe37bda033fc383')">湖南省</button>
#             <button class="tablinks" onclick="showChart(event, '606deebd2c18498f9d837f1c059e51bf')">甘肃省</button>
#             <button class="tablinks" onclick="showChart(event, '841467fc078c4002a83576282a814f29')">福建省</button>
#             <button class="tablinks" onclick="showChart(event, '06f8b78a688c4bc690d4587d5e6eaed3')">贵州省</button>
#             <button class="tablinks" onclick="showChart(event, 'b88620f760ff46b698c0ede8f5ec8c09')">辽宁省</button>
#             <button class="tablinks" onclick="showChart(event, 'f1373acaf9eb46628dafeae3e88f21f5')">重庆市</button>
#             <button class="tablinks" onclick="showChart(event, 'f8e4355b16404ac0a3be68f084231a84')">陕西省</button>
#             <button class="tablinks" onclick="showChart(event, '34690729fc334ce089cccae1815dcb9d')">青海省</button>
#             <button class="tablinks" onclick="showChart(event, 'c5ded6b308d94bfc9a80bf07068146d8')">黑龙江省</button>
#     </div>
#
#         <div id="230a4ae03d3a42fbb4f938605a12e93a" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="dc74811c4c374729b2b95da312cdd44a" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="3af75c85c0a54795a820783581385470" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="8b1b83f6f6e34894a3f2be5bc48e3434" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="9df5a6a829374e6d842f865ececadce8" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="85eb276e378a4f5baaabaef1080f177a" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="9544e813a1ee4871aefe15eea149ffc3" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="69b86ff87428479c98cd6afdd4d3fb4e" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="68e3d9eb654347059b7ff4e536599966" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="d07627d02e734b06ab3d0ea216f3ba4d" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="8eb41c448e8a4e61b29342942edca305" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="517b6a8186844203b552fe045cf2ff63" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="f54a4169873e4e03a1989301d244354f" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="21550f79d429466e8082efc08978a59a" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="a72a4b28ad284474867d3cb6b89e873c" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="1b2d5e24960c45ad9d56a757cec47b69" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="a14428bf62c04651a17044416a76f187" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="3a049cda910b43ac92f8de648008d0cc" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="0f63742aa76a4729bfe37bda033fc383" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="606deebd2c18498f9d837f1c059e51bf" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="841467fc078c4002a83576282a814f29" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="06f8b78a688c4bc690d4587d5e6eaed3" class="chart-container" style="width:900px; height:500
